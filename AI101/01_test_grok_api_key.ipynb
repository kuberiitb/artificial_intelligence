# %% [markdown]
# <a href="https://colab.research.google.com/github/kuberiitb/artificial_intelligence/blob/main/AI101/01_test_grok_api_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install required pckages

# %%
# !pip install langchain-groq langchain --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.8/495.8 kB 14.7 MB/s eta 0:00:00

# %% [markdown]
# ## Import required pckages

# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# ## Load the GROK KEY
# - This step is necessary for the safety of your key
# - Upload your .env file in colab with the values in this format:
# - ```GROQ_API_KEY=<KEY YOU COPIED>```
# - Then load the key with below command using dotenv package.

# %%
from dotenv import load_dotenv
load_dotenv("/content/.env")
# Out:
# True

# %% [markdown]
# ### Above command output should say True, otherwise your keys are not loaded.
#
# ### Setting GROQ_API_KEY to environment so that langchain can access it

# %%
if not os.environ["GROQ_API_KEY"]:
  os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
# Initialize the Groq LLM
llm = ChatGroq(model_name="llama-3.1-8b-instant", temperature=0.7)

response = llm.invoke([
    ("system", """You are a helpful assistant.
    """),
    ("user", "Hi")
])

print(response.content)
# Out:
# How can I assist you today?

# %% [markdown]
# ### If you see a message like **How can I assist you today?**, your set and key is working.
# ### Otherwise, you need to fix it.

# %% [markdown]
# ### Now let's learn how to set a prompt template and chain.

# %%
# Define a prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", """You are a helpful assistant. Answer in 1-2 lines only.
    """),
    ("user", "{input}")
])

# Create a chain
chain = prompt | llm

# %%
test_input = "What is Python?"

# Invoke the chain
response = chain.invoke({"input": test_input})
print(response.content)
# Out:
# Python is a high-level, interpreted programming language known for its simplicity, readability, and versatility. It's commonly used for web development, data analysis, artificial intelligence, and automation tasks.
